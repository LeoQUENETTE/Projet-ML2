# %%
def reload_modules():
    """Recharge tous les modules personnalisés"""
    import importlib
    import sys
    
    modules_to_reload = [
        'functions.create_X_Y',
        'functions.download_data_from_poncelet', 
        'classes.Config'
        # Ajoutez tous vos modules
    ]
    
    for module_name in modules_to_reload:
        if module_name in sys.modules:
            importlib.reload(sys.modules[module_name])

# %%
# !git clone https://github.com/LeoQUENETTE/Projet-ML2.git
# %cd Projet-ML2
# !git checkout leo
# %pwd
# !git branch -a
# !git pull
reload_modules()
# Out:
# fatal: destination path 'Projet-ML2' already exists and is not an empty directory.
# /content/Projet-ML2/Projet-ML2
# Already on 'leo'
# Your branch is up to date with 'origin/leo'.
# * leo
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/images
#   remotes/origin/leo
#   remotes/origin/main
#   remotes/origin/textes
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 76 (delta 55), reused 47 (delta 26), pack-reused 0 (from 0)
# Unpacking objects: 100% (76/76), 17.23 KiB | 504.00 KiB/s, done.
# From https://github.com/LeoQUENETTE/Projet-ML2
#    172e193..00b8875  leo        -> origin/leo
# Updating 172e193..00b8875
# Fast-forward
#  .vscode/settings.json                              |   6 +
#  src/classes/Config.py                              |   8 +-
#  src/classif_textes_launcher.ipynb                  | 215 ++++++++++++++++-----
# ...

# %% [markdown]
# ## Importation des fichiers

# %%
# !pip install -r requirements.txt #Si les imports ne sont pas présents

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('./src'))
sys.path.insert(0, os.path.abspath('./src/functions'))
sys.path.insert(0, os.path.abspath('./src/classes'))

# %% [markdown]
# ## Partie code

# %%
from Config import *
from create_X_Y import *
from download_data_from_poncelet import *

df = download_data_from_poncelet()
config = Config()
X, y = create_x_y(config.sequence_lenght, df)
# Out:
# Téléchargement de flickr_subset2.zip...
# Téléchargement réussi. Extraction...
# Données extraites dans : flickr_subset2
# test create X Y
