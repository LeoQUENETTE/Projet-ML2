# %%
# !git clone https://github.com/LeoQUENETTE/Projet-ML2.git
# %cd Projet-ML2
# !git checkout leo
# %pwd
# !git branch -a
# !git pull
# Out:
# Cloning into 'Projet-ML2'...
# remote: Enumerating objects: 113, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 113 (delta 45), reused 62 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (113/113), 8.31 MiB | 16.62 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2
# Branch 'leo' set up to track remote branch 'leo' from 'origin'.
# Switched to a new branch 'leo'
# * leo
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/images
#   remotes/origin/leo
#   remotes/origin/main
#   remotes/origin/textes
# Already up to date.

# %%
# %ls ./src/functions
# Out:
# create_X_Y.py                   __init__.py
# download_data_from_poncelet.py  preview_images_from_dir.py

# %% [markdown]
# ## Importation des fichiers

# %%
# !pip install -r requirements.txt #Si les imports ne sont pas présents

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('./src'))
sys.path.insert(0, os.path.abspath('./src/functions'))
sys.path.insert(0, os.path.abspath('./src/classes'))

# %% [markdown]
# ## Partie code

# %%
from Config import *
from create_X_Y import *
from download_data_from_poncelet import *
config = Config()
df = download_data_from_poncelet()
create_x_y(config.sequence_lenght, df)
# Out:
# Téléchargement de flickr_subset2.zip...
# Téléchargement réussi. Extraction...
# Données extraites dans : flickr_subset2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3596115266.py in <cell line: 0>()
#       4 config = Config()
#       5 df = download_data_from_poncelet()
# ----> 6 create_x_y(config.sequence_lenght, config.ma)
#
# AttributeError: 'Config' object has no attribute 'ma'
