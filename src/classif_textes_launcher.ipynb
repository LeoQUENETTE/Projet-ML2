# %%
# !git clone https://github.com/LeoQUENETTE/Projet-ML2.git
# %cd Projet-ML2
# !git checkout leo
# %pwd
# !git branch -a
# !git pull
# Out:
# Cloning into 'Projet-ML2'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 84 (delta 28), reused 40 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 8.30 MiB | 16.13 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/Projet-ML2
# Branch 'leo' set up to track remote branch 'leo' from 'origin'.
# Switched to a new branch 'leo'
# * leo
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/images
#   remotes/origin/leo
#   remotes/origin/main
#   remotes/origin/textes
# Already up to date.

# %%
# %cd src
# %ls
# %pwd
import sys
sys.path.append('/content/Projet-ML2/src/classes')
from Config import *
# Out:
# [Errno 2] No such file or directory: 'src'
# /content/Projet-ML2/src
# classes/  classif_textes_launcher.ipynb  functions/
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3005157803.py in <cell line: 0>()
#       4 import sys
#       5 sys.path.append('/content/Projet-ML2/src/classes')
# ----> 6 from Config import *
#
# ModuleNotFoundError: No module named 'Config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
config = Config()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-527602628.py in <cell line: 0>()
# ----> 1 config = Config()
#
# NameError: name 'Config' is not defined
