# %%
# !git clone https://github.com/LeoQUENETTE/Projet-ML2.git
# %cd Projet-ML2
# !git checkout leo
# %pwd
# !git branch -a
# !git pull
# Out:
# Cloning into 'Projet-ML2'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 145 (delta 70), reused 83 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (145/145), 8.32 MiB | 16.89 MiB/s, done.
# Resolving deltas: 100% (70/70), done.
# /content/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2
# Branch 'leo' set up to track remote branch 'leo' from 'origin'.
# Switched to a new branch 'leo'
# * leo
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/images
#   remotes/origin/leo
#   remotes/origin/main
#   remotes/origin/textes
# Already up to date.

# %%
# %ls ./src/functions
# Out:
# create_X_Y.py                   __init__.py
# download_data_from_poncelet.py  preview_images_from_dir.py

# %% [markdown]
# ## Importation des fichiers

# %%
# !pip install -r requirements.txt #Si les imports ne sont pas présents

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('./src'))
sys.path.insert(0, os.path.abspath('./src/functions'))
sys.path.insert(0, os.path.abspath('./src/classes'))

# %% [markdown]
# ## Partie code

# %%
from Config import *
from create_X_Y import *
from download_data_from_poncelet import *
import pandas as pd
config = Config()
result = download_data_from_poncelet()
df_csv = pd.read_csv("flickr_subset2/captions.csv")

# Use the correct one
df = result if result is not None else df_csv
print(type(config.sequence_lenght))
print(type(df))
print( "erreur" if df is None else "pas d'erreur")
create_x_y(config.sequence_lenght, df)
# Out:
# Données déjà disponibles dans : flickr_subset2
# <class 'int'>
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2165866460.py in <cell line: 0>()
#      11 print(type(config.sequence_lenght))
#      12 print(type(df))
# ---> 13 create_x_y(config.sequence_lenght, df)
#      14
#
# TypeError: create_x_y() missing 1 required positional argument: 'df'
