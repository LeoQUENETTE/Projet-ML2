# %%
# !git clone https://github.com/LeoQUENETTE/Projet-ML2.git
# %cd Projet-ML2
# !git checkout leo
# %pwd
# !git branch -a
# !git pull
# Out:
# Cloning into 'Projet-ML2'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 102 (delta 36), reused 55 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 8.31 MiB | 15.11 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/Projet-ML2/Projet-ML2/Projet-ML2/Projet-ML2
# Branch 'leo' set up to track remote branch 'leo' from 'origin'.
# Switched to a new branch 'leo'
# * leo
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/images
#   remotes/origin/leo
#   remotes/origin/main
#   remotes/origin/textes
# Already up to date.

# %%
# %ls ./src/functions
# Out:
# create_X_Y.py  download_data_from_poncelet.py  preview_images_from_dir.py

# %% [markdown]
# ## Importation des fichiers

# %%
# !pip install -r requirements.txt #Si les imports ne sont pas présents

# %%
import sys
sys.path.append('./src')
sys.path.append('./src/classes')
sys.path.append('./src/functions')

# %% [markdown]
# ## Partie code

# %%
from Config import *
from src.functions.create_X_Y import *
config = Config()
create_X_Y()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1859283481.py in <cell line: 0>()
#       1 from Config import *
# ----> 2 from src.functions.create_X_Y import create_X_Y
#       3 config = Config()
#       4 create_X_Y()
#
# ModuleNotFoundError: No module named 'src.functions.create_X_Y'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
